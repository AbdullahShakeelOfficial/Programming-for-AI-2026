# %% [markdown]
# # Week 1 Python Fundamentals
# This notebook demonstrates basic Python operations including variables, data types, and user input handling.

# %%
name = "Hafiz Abdullah Shakeel"
program = "BS Artificial Intelligence"
print(f"Name: {name}")
print(f"Program: {program}")
# Out:
# Name: Hafiz Abdullah Shakeel
# Program: BS Artificial Intelligence

# %%
student_count = 40
average_cgpa = 3.25
is_ai_student = True
course_name = "Programming for AI"

print(student_count, type(student_count))
print(average_cgpa, type(average_cgpa))
print(is_ai_student, type(is_ai_student))
print(course_name, type(course_name))
# Out:
# 40 <class 'int'>
# 3.25 <class 'float'>
# True <class 'bool'>
# Programming for AI <class 'str'>

# %% [markdown]
# ### Why `input()` returns a string
# The `input()` function always reads input from the user as plain text/sequence of characters (a string). This allows Python to accept any keyboard input without assuming a data type upfront. To perform mathematical calculations, we must explicitly convert string values using `int()` or `float()`.
